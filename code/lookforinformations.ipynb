# %%
import geatpy as ea

# %%
help(ea.varplot)
# Out:
# Help on cython_function_or_method in module varplot:
#
# varplot(Vars, Label='', saveFlag=None, ax=None, gen=None, interval=0.01, title='', save_path='')
#     varplot : function - 决策变量绘图函数
#
#     描述:
#         该函数绘制决策变量在决策空间中的静态或动态图像，当决策变量维数是2或3时，本函数绘制的是决策变量在决策空间中的点，
#         当维数为1或大于3时，本函数绘制的是各决策变量在各维度上的值。
#
#     语法:
#         newAx = varplot(Vars, Label, saveFlag)
#         newAx = varplot(Vars, Label, saveFlag, ax)
#         newAx = varplot(Vars, Label, saveFlag, ax, gen)
#         newAx = varplot(Vars, Label, saveFlag, ax, gen, interval)
#         newAx = varplot(Vars, Label, saveFlag, ax, gen, interval, title)
#         newAx = varplot(Vars, Label, saveFlag, ax, gen, interval, title, save_path)
#
#     输入参数:
#         Vars      : array  - 存储种群决策变量值的矩阵，每行对应一个个体的所有决策变量值，每列对应一个决策变量。
#
#         Label     : string - (可选参数)绘图中的标签，当缺省或为None时，默认为空字符串。
#
#         saveFlag  : bool   - (可选参数)是否保存图片，
#                              True表示保存; False表示不保存。当缺省或为None时，默认为False。
#
# ...

# %%
help(ea.crtfld)
# Out:
# Help on cython_function_or_method in module crtfld:
#
# crtfld(Encoding, varTypes, ranges, borders=None, precisions=None, codes=None, scales=None)
#     crtfld : function - 译码矩阵生成函数
#
#     描述：该函数根据输入的参数生成译码矩阵FieldD或FieldDR。
#
#     语法:
#         当Encoding为'RI'或'P'时：
#         FieldDR = crtfld(Encoding, varTypes, ranges, borders)
#         FieldDR = crtfld(Encoding, varTypes, ranges, borders, contraction)
#         当Encoding为'BG'时：
#         FieldD = crtfld(Encoding, varTypes, ranges, borders, precisions)
#         FieldD = crtfld(Encoding, varTypes, ranges, borders, precisions, codes)
#         FieldD = crtfld(Encoding, varTypes, ranges, borders, precisions, codes, scales)
#
#     输入参数:
#         Encoding : str   - 染色体编码方式，
#                            'BG':二进制/格雷编码；
#                            'RI':实整数编码，即实数和整数的混合编码；
#                            'P':排列编码。
#                            相关概念：“实值编码”包含实整数编码和排列编码，
#                            它们共同的特点是染色体不需要解码即可直接表示对应的决策变量。
# ...

# %%
import geatpy as ea
help(ea.Population)
# Out:
# Help on class Population in module Population:
#
# class Population(builtins.object)
#  |  Population : class - 种群类
#  |
#  |  描述:
#  |      种群类是用来存储种群相关信息的一个类。
#  |
#  |  属性:
#  |      sizes    : int   - 种群规模，即种群的个体数目。
#  |
#  |      Lind     : int   - 种群染色体长度。
#  |
#  |      Encoding : str   - 染色体编码方式，
#  |                         'BG':二进制/格雷编码；
#  |                         'RI':实整数编码，即实数和整数的混合编码；
#  |                         'P':排列编码。
#  |                         相关概念：术语“实值编码”包含实整数编码和排列编码，
#  |                         它们共同的特点是染色体不需要解码即可直接表示对应的决策变量。
#  |                         "实整数"指的是种群染色体既包含实数的小数，也包含实数的整数。
#  |
#  |      Field    : array - 译码矩阵，可以是FieldD或FieldDR（详见Geatpy数据结构）。
#  |
#  |      Chrom    : array - 种群染色体矩阵，每一行对应一个个体的一条染色体。
#  |
#  |      ObjV     : array - 种群目标函数值矩阵，每一行对应一个个体的目标函数值，每一列对应一个目标。
#  |
#  |      FitnV    : array - 种群个体适应度列向量，每个元素对应一个个体的适应度，最小适应度为0。
#  |
#  |      CV       : array - CV(Constraint Violation Value)是用来定量描述违反约束条件程度的矩阵，每行对应一个个体，每列对应一个约束。
# ...

# %%
help(ea.Population.FieldDR)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-a4411ed96805> in <module>()
# ----> 1 help(ea.Population.FieldDR)
#
# AttributeError: type object 'Population' has no attribute 'FieldDR'

# %%
help(ea.crtrp)
# Out:
# Help on cython_function_or_method in module crtrp:
#
# crtrp(Nind, FieldDR)
#     crtrp : function - (Create Real-number Points)创建一个实数值种群染色体矩阵。
#
#     描述：
#         该函数创建一个元素服从均匀分布随机数的实数值种群染色体矩阵。
#
#     语法:
#         Chrom = crtrp(Nind, FieldDR)
#
#     输入参数:
#         Nind    : int   -  代表种群的个体数。
#
#         FieldDR : array - 实值编码种群译码矩阵，Encoding为'RI'或'P'时使用的是这种结构的译码矩阵。
#             [lb;             指明每个变量使用的下界。
#              ub;             指明每个变量使用的上界。
#              varTypes] (0:continued | 1:discrete)。
#             注：不需要考虑是否包含变量的边界值。在crtfld中已经将是否包含边界值进行了处理，
#                本函数生成的矩阵的元素值在FieldDR的[下界, 上界)之间。
#
#     输出参数:
#         Chrom : array - 一个以种群个体数为行数、以染色体长度为列数的元素为随机实数值的矩阵。
#
#     Created on Mon Mar 26 14:20:40 2018
#     @author: jazzbin
#
#     Update on Sat Oct 20 22:29:12 2018
#     @author: Whale

# %%
help(ea.mutde)
# Out:
# Help on cython_function_or_method in module mutde:
#
# mutde(Encoding, OldChrom, FieldDR, r0, F=0.5, DN=1, Loop=False, params7=None)
#     mutde : function - 差分变异(Mutation for Differential Evolution)
#
#     描述:
#         该函数让一个实整数编码种群染色体矩阵（Encoding为'RI'）进行差分变异，返回一个新的种群染色体矩阵。
#         基向量矩阵Xr0由传入参数r0(或Xr0)确定，差分向量索引r1,r2(乃至r3,r4)按照随机的方式确定，
#         并尽可能保证互不相等（当种群个体数过小时无法保证）。
#         每条染色体的变异结果 = Xr0 + F*(Xr1 - Xr2)或者 = Xr0 + F*(Xr1 - Xr2 + Xr3 - Xr4)。
#         该函数先是采用实数值来进行变异，
#         当结果超出译码矩阵FieldDR所设定的范围时，该函数会把超出的部分设为与之的范围边界值，
#         然后根据译码矩阵FieldDR用四舍五入法把变异结果中需要转换的部分转换为整数。
#         注意：该函数不会检查边界范围的设置是否有误，因此建议采用crtfld函数对边界进行预处理。
#
#     语法:
#         NewChrom = mutde(Encoding, OldChrom, FieldDR, r0)
#         NewChrom = mutde(Encoding, OldChrom, FieldDR, r0, F)
#         NewChrom = mutde(Encoding, OldChrom, FieldDR, r0, F, DN)
#         NewChrom = mutde(Encoding, OldChrom, FieldDR, r0, F, DN, Loop)
# ...

# %%
import geatpy as ea
help(ea.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     )
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-92f4e73acc6f> in <module>()
#       1 import geatpy as ea
# ----> 2 help(ea.XOVR)
#
# AttributeError: module 'geatpy' has no attribute 'XOVR'

# %%
help(ea.Xovbd)
# Out:
# Help on class Xovbd in module operators.recombination.Xovbd:
#
# class Xovbd(operators.recombination.Recombination.Recombination)
#  |  Xovbd - class : 一个用于调用内核中的函数xovbd(二项式分布交叉)的类，
#  |                  该类的各成员属性与内核中的对应函数的同名参数含义一致，
#  |                  可利用help(xovbd)查看各参数的详细含义及用法。
#  |
#  |  Method resolution order:
#  |      Xovbd
#  |      operators.recombination.Recombination.Recombination
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, XOVR=0.7, Half=False, GeneID=None)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  do(self, OldChrom)
#  |
#  |  getHelp(self)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from operators.recombination.Recombination.Recombination:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %%
help(ea.xovbd)
# Out:
# Help on cython_function_or_method in module xovbd:
#
# xovbd(OldChrom, XOVR=0.7, Half=False, GeneID=None, params4=None)
#     xovbd : function - 二项式分布交叉(Binomial Distribution Crossover)
#
#     描述:
#         该函数把输入的OldChrom染色体矩阵进行二项式分布交叉，并返回新的种群染色体矩阵。
#         交配的一对是有序的，种群的前一半个体和后一半个体进行配对。
#         若个体数是奇数，则最后一个个体不参与配对。
#         具体交叉方法详见文献[1]。
#         当传入该函数的第一个参数是list类型时，该参数表示的是OldChroms而不是OldChrom，
#         此时表示种群个体拥有多条染色体，因此交叉的作用域不再是染色体的片段，而是整条染色体。
#         例如：OldChroms = [OldChrom1, OldChrom2],
#         OldChrom1=[[1,2,3],
#                    [1,3,4]]
#         OldChrom2=[[2,2,3],
#                    [2,3,4]]
#         则交叉结果可能为：
#         OldChrom1=[[1,2,3],
#                    [1,3,4]]
#         OldChrom2=[[2,3,4],
#                    [2,2,3]]
#
#     语法:
#         NewChrom =  xovbd(OldChrom)
#         NewChrom =  xovbd(OldChrom, XOVR)
#         NewChrom =  xovbd(OldChrom, XOVR, Half)
#         NewChrom =  xovbd(OldChrom, XOVR, Half, GeneID)
# ...

# %%
help(ea.selecting)
# Out:
# Help on cython_function_or_method in module selecting:
#
# selecting(SEL_F, FitnV, GGAP=1.0)
#     selecting.py - 高级选择函数
#
#     描述：
#         该函数调用了低级选择函数对种群个体进行选择。
#
#     语法：
#         NewChrIx = selecting(SEL_F, FitnV)
#         NewChrIx = selecting(SEL_F, FitnV, GGAP)
#         NewChrIx = selecting(SEL_F, FitnV, NSel)
#
#     输入参数：
#         SEL_F     : string   - 低级选择函数名称
#
#         FitnV     : array    - 种群适应度列向量
#
#         GGAP/NSel : float    - (可选参数)当取值为[0,1]时是GGAP（代沟），
#                                表示被选择的个体在种群中的占比,默认为1.0，
#                                当其大于1时，不再表示代沟，而表示每个子种群所要选择的个体数NSel（NSel将向上取整）
#                                若想要只选择1个个体，则应设置该值为0，当GGAP为0时，NSel将被赋值为1
#
#     返回参数:
#         NewChrIx  : array    - 被选择个体的索引号（行向量）。
#
#     注意:
#         1.本函数是根据FitnV来进行选择的，与ObjV无关，因此在调用本函数前，不需要对传入的ObjV乘上
#           ’maxormins’(最大最小化标记)，对于返回的ObjVSel，也不需要乘上’maxormins’进行还原。
#         2.种群个体数及想要选择的个体数必须均能够被子种群数整除。
#
#     历史:
# ...

# %%
help(ea.sus)
# Out:
# Help on cython_function_or_method in module sus:
#
# sus(FitnV, Nsel)
#     sus : function - (Stochastic Universal Sampling)随机抽样选择
#
#     描述:
#         该函数根据种群中个体的适应度FitnV，有概率地选择Nsel个个体。
#
#     语法:
#         NewChrIx = sus(FitnV, Nsel)
#
#     输入参数:
#         FitnV : array - 种群适应度列向量。
#
#         Nsel  : int   - 被选择个体的数目，可以比父代多。
#
#     输出参数:
#         NewChrIx : array - 一个记录着被选择个体索引的行向量。
#
#     Created on Thu May 10 20:44:11 2018
#
#     @author: jazzbin

# %%
help(xovr)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-48b0618a351c> in <module>()
# ----> 1 help(xovr)
#
# NameError: name 'xovr' is not defined

# %%
help(ea.urs)
# Out:
# Help on cython_function_or_method in module urs:
#
# urs(FitnV, Nsel)
#     urs : function - (Uncommitted Random Selection)无约束随机选择
#
#     描述:
#         该函数实现无约束的随机选择，返回被选择的个体索引。
#
#     语法:
#         NewChrIx = urs(FitnV, Nsel)
#
#     输入参数:
#         FitnV : array - 种群适应度列向量。FitnV在该函数的作用仅仅是用来确定种群规模。
#
#         Nsel  : int   - 被选择个体的数目，可以比父代多。
#
#     输出参数:
#         NewChrIx : array - 一个记录着被选择个体索引的行向量。
#
#     Created on Mon Jul 15 00:40:56 2019
#
#     @author: jazzbin

# %%
help(ea.mutate)
# Out:
# Help on cython_function_or_method in module mutate:
#
# mutate(MUT_F, Encoding, OldChrom, params2=None, params3=None, params4=None, params5=None, params6=None, params7=None)
#     mutate : function - 高级变异函数
#
#     描述:
#         该函数接收一个种群染色体矩阵，对个体进行变异并返回新的种群矩阵，
#         该函数调用低级突变函数来进行突变。
#
#     语法:
#         NewChrom = mutate(MUT_F, Encoding, OldChrom)
#         NewChrom = mutate(MUT_F, Encoding, OldChrom, params2)
#         NewChrom = mutate(MUT_F, Encoding, OldChrom, params2, params3)
#         NewChrom = mutate(MUT_F, Encoding, OldChrom, params2, params3, params4)
#         NewChrom = mutate(MUT_F, Encoding, OldChrom, params2, params3, params4, params5)
#         NewChrom = mutate(MUT_F, Encoding, OldChrom, params2, params3, params4, params5, params6)
#         NewChrom = mutate(MUT_F, Encoding, OldChrom, params2, params3, params4, params5, params6, params7)
#
#     输入参数:
#         MUT_F     : string- 低级变异函数的字符串，比如'mutbga'等。
#
#         Encoding : str   - 染色体编码方式，
# ...

# %%
import geatpy as ea
help(ea.Population)
# Out:
# Help on class Population in module Population:
#
# class Population(builtins.object)
#  |  Population : class - 种群类
#  |
#  |  描述:
#  |      种群类是用来存储种群相关信息的一个类。
#  |
#  |  属性:
#  |      sizes    : int   - 种群规模，即种群的个体数目。
#  |
#  |      Lind     : int   - 种群染色体长度。
#  |
#  |      Encoding : str   - 染色体编码方式，
#  |                         'BG':二进制/格雷编码；
#  |                         'RI':实整数编码，即实数和整数的混合编码；
#  |                         'P':排列编码。
#  |                         相关概念：术语“实值编码”包含实整数编码和排列编码，
#  |                         它们共同的特点是染色体不需要解码即可直接表示对应的决策变量。
#  |                         "实整数"指的是种群染色体既包含实数的小数，也包含实数的整数。
#  |
#  |      Field    : array - 译码矩阵，可以是FieldD或FieldDR（详见Geatpy数据结构）。
#  |
#  |      Chrom    : array - 种群染色体矩阵，每一行对应一个个体的一条染色体。
#  |
#  |      ObjV     : array - 种群目标函数值矩阵，每一行对应一个个体的目标函数值，每一列对应一个目标。
#  |
#  |      FitnV    : array - 种群个体适应度列向量，每个元素对应一个个体的适应度，最小适应度为0。
#  |
#  |      CV       : array - CV(Constraint Violation Value)是用来定量描述违反约束条件程度的矩阵，每行对应一个个体，每列对应一个约束。
# ...

# %%
help(ea.Problem)
# Out:
# Help on class Problem in module Problem:
#
# class Problem(builtins.object)
#  |  Problem : Class - 问题类
#  |
#  |  描述:
#  |      问题类是用来存储与待求解问题相关信息的一个类。
#  |
#  |  属性:
#  |      name      : str   - 问题名称（可以自由设置名称）。
#  |
#  |      M         : int   - 目标维数，即有多少个优化目标。
#  |
#  |      maxormins : list  - 目标最小最大化标记列表，1表示最小化，-1表示最大化，例如：
#  |                          [1,1,-1,-1]，表示前2个目标是最小化，后2个目标是最大化。
#  |
#  |      Dim       : int   - 决策变量维数，即有多少个决策变量。
#  |
#  |      varTypes  : array - 连续或离散标记，是Numpy array类型的行向量，
#  |                          0表示对应的决策变量是连续的；1表示对应的变量是离散的。
#  |
#  |      ranges    : array - 决策变量范围矩阵，第一行对应决策变量的下界，第二行对应决策变量的上界。
#  |
#  |      borders   : array - 决策变量范围的边界矩阵，第一行对应决策变量的下边界，第二行对应决策变量的上边界，
#  |                          0表示范围中不含边界，1表示范围包含边界。
#  |
#  |  函数:
#  |      aimFunc(pop) : 目标函数，需要在继承类即自定义的问题类中实现，或是传入已实现的函数。
#  |                     其中pop为Population类的对象，代表一个种群，
#  |                     pop对象的Phen属性（即种群染色体的表现型）等价于种群所有个体的决策变量组成的矩阵，
# ...

# %%
help(type(ea.Problem))
# Out:
# Help on class type in module builtins:
#
# class type(object)
#  |  type(object_or_name, bases, dict)
#  |  type(object) -> the object's type
#  |  type(name, bases, dict) -> a new type
#  |
#  |  Methods defined here:
#  |
#  |  __call__(self, /, *args, **kwargs)
#  |      Call self as a function.
#  |
#  |  __delattr__(self, name, /)
#  |      Implement delattr(self, name).
#  |
#  |  __dir__(...)
#  |      __dir__() -> list
#  |      specialized __dir__ implementation for types
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __init__(self, /, *args, **kwargs)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __instancecheck__(...)
#  |      __instancecheck__() -> bool
#  |      check if an object is an instance
#  |
#  |  __new__(*args, **kwargs)
#  |      Create and return a new object.  See help(type) for accurate signature.
#  |
#  |  __prepare__(...)
#  |      __prepare__() -> dict
# ...

# %%
help(ea.crtfld)
# Out:
# Help on cython_function_or_method in module crtfld:
#
# crtfld(Encoding, varTypes, ranges, borders=None, precisions=None, codes=None, scales=None)
#     crtfld : function - 译码矩阵生成函数
#
#     描述：该函数根据输入的参数生成译码矩阵FieldD或FieldDR。
#
#     语法:
#         当Encoding为'RI'或'P'时：
#         FieldDR = crtfld(Encoding, varTypes, ranges, borders)
#         FieldDR = crtfld(Encoding, varTypes, ranges, borders, contraction)
#         当Encoding为'BG'时：
#         FieldD = crtfld(Encoding, varTypes, ranges, borders, precisions)
#         FieldD = crtfld(Encoding, varTypes, ranges, borders, precisions, codes)
#         FieldD = crtfld(Encoding, varTypes, ranges, borders, precisions, codes, scales)
#
#     输入参数:
#         Encoding : str   - 染色体编码方式，
#                            'BG':二进制/格雷编码；
#                            'RI':实整数编码，即实数和整数的混合编码；
#                            'P':排列编码。
#                            相关概念：“实值编码”包含实整数编码和排列编码，
#                            它们共同的特点是染色体不需要解码即可直接表示对应的决策变量。
# ...

# %%
help(ea.Population)
# Out:
# Help on class Population in module Population:
#
# class Population(builtins.object)
#  |  Population : class - 种群类
#  |
#  |  描述:
#  |      种群类是用来存储种群相关信息的一个类。
#  |
#  |  属性:
#  |      sizes    : int   - 种群规模，即种群的个体数目。
#  |
#  |      Lind     : int   - 种群染色体长度。
#  |
#  |      Encoding : str   - 染色体编码方式，
#  |                         'BG':二进制/格雷编码；
#  |                         'RI':实整数编码，即实数和整数的混合编码；
#  |                         'P':排列编码。
#  |                         相关概念：术语“实值编码”包含实整数编码和排列编码，
#  |                         它们共同的特点是染色体不需要解码即可直接表示对应的决策变量。
#  |                         "实整数"指的是种群染色体既包含实数的小数，也包含实数的整数。
#  |
#  |      Field    : array - 译码矩阵，可以是FieldD或FieldDR（详见Geatpy数据结构）。
#  |
#  |      Chrom    : array - 种群染色体矩阵，每一行对应一个个体的一条染色体。
#  |
#  |      ObjV     : array - 种群目标函数值矩阵，每一行对应一个个体的目标函数值，每一列对应一个目标。
#  |
#  |      FitnV    : array - 种群个体适应度列向量，每个元素对应一个个体的适应度，最小适应度为0。
#  |
#  |      CV       : array - CV(Constraint Violation Value)是用来定量描述违反约束条件程度的矩阵，每行对应一个个体，每列对应一个约束。
# ...

# %%
help(ea.mutde)
# Out:
# Help on cython_function_or_method in module mutde:
#
# mutde(Encoding, OldChrom, FieldDR, r0, F=0.5, DN=1, Loop=False, params7=None)
#     mutde : function - 差分变异(Mutation for Differential Evolution)
#
#     描述:
#         该函数让一个实整数编码种群染色体矩阵（Encoding为'RI'）进行差分变异，返回一个新的种群染色体矩阵。
#         基向量矩阵Xr0由传入参数r0(或Xr0)确定，差分向量索引r1,r2(乃至r3,r4)按照随机的方式确定，
#         并尽可能保证互不相等（当种群个体数过小时无法保证）。
#         每条染色体的变异结果 = Xr0 + F*(Xr1 - Xr2)或者 = Xr0 + F*(Xr1 - Xr2 + Xr3 - Xr4)。
#         该函数先是采用实数值来进行变异，
#         当结果超出译码矩阵FieldDR所设定的范围时，该函数会把超出的部分设为与之的范围边界值，
#         然后根据译码矩阵FieldDR用四舍五入法把变异结果中需要转换的部分转换为整数。
#         注意：该函数不会检查边界范围的设置是否有误，因此建议采用crtfld函数对边界进行预处理。
#
#     语法:
#         NewChrom = mutde(Encoding, OldChrom, FieldDR, r0)
#         NewChrom = mutde(Encoding, OldChrom, FieldDR, r0, F)
#         NewChrom = mutde(Encoding, OldChrom, FieldDR, r0, F, DN)
#         NewChrom = mutde(Encoding, OldChrom, FieldDR, r0, F, DN, Loop)
# ...

# %%
help(ea.sus)
# Out:
# Help on cython_function_or_method in module sus:
#
# sus(FitnV, Nsel)
#     sus : function - (Stochastic Universal Sampling)随机抽样选择
#
#     描述:
#         该函数根据种群中个体的适应度FitnV，有概率地选择Nsel个个体。
#
#     语法:
#         NewChrIx = sus(FitnV, Nsel)
#
#     输入参数:
#         FitnV : array - 种群适应度列向量。
#
#         Nsel  : int   - 被选择个体的数目，可以比父代多。
#
#     输出参数:
#         NewChrIx : array - 一个记录着被选择个体索引的行向量。
#
#     Created on Thu May 10 20:44:11 2018
#
#     @author: jazzbin

# %%
help(ea.Population)
# Out:
# Help on class Population in module Population:
#
# class Population(builtins.object)
#  |  Population : class - 种群类
#  |
#  |  描述:
#  |      种群类是用来存储种群相关信息的一个类。
#  |
#  |  属性:
#  |      sizes    : int   - 种群规模，即种群的个体数目。
#  |
#  |      Lind     : int   - 种群染色体长度。
#  |
#  |      Encoding : str   - 染色体编码方式，
#  |                         'BG':二进制/格雷编码；
#  |                         'RI':实整数编码，即实数和整数的混合编码；
#  |                         'P':排列编码。
#  |                         相关概念：术语“实值编码”包含实整数编码和排列编码，
#  |                         它们共同的特点是染色体不需要解码即可直接表示对应的决策变量。
#  |                         "实整数"指的是种群染色体既包含实数的小数，也包含实数的整数。
#  |
#  |      Field    : array - 译码矩阵，可以是FieldD或FieldDR（详见Geatpy数据结构）。
#  |
#  |      Chrom    : array - 种群染色体矩阵，每一行对应一个个体的一条染色体。
#  |
#  |      ObjV     : array - 种群目标函数值矩阵，每一行对应一个个体的目标函数值，每一列对应一个目标。
#  |
#  |      FitnV    : array - 种群个体适应度列向量，每个元素对应一个个体的适应度，最小适应度为0。
#  |
#  |      CV       : array - CV(Constraint Violation Value)是用来定量描述违反约束条件程度的矩阵，每行对应一个个体，每列对应一个约束。
# ...

# %%
help(ea.scaling)
# Out:
# Help on cython_function_or_method in module scaling:
#
# scaling(ObjV, CV=None, Smul=2.0)
#     scaling : function - 线性尺度变换适应度计算
#
#     描述:
#         该函数对个体的目标函数值通过线性尺度变换来计算对应的适应度，
#         遵循"目标函数越大适应度越小"的约定，
#         该函数计算的适应度遵循"适应度最小值为0"的约定。
#
#     语法:
#         FitnV = scaling(ObjV)
#         FitnV = scaling(ObjV, CV)
#         FitnV = scaling(ObjV, CV, Smul)
#
#     输入参数:
#         ObjV   : array - 一个保存着个体对应的目标函数值的列向量。
#
#         CV     : array - (可选参数)种群个体违反约束程度矩阵，当缺省或为None时，默认种群所有个体都是可行的。
#
#         Smul   : float - (可选参数)线性变换的决定上界的常数，详见注释里的算法描述部分,
#                          若缺省或为None或Nan,则默认为2。
#
#     输出参数:
#         FitnV  : array - 记录着种群个体适应度值的列向量。
#
#     算法描述:
#         在对目标函数值ObjV进行线性变换时，受到参数Smul的影响，
#         变换公式：F' = aF + b，
#         其中F为直接拿目标函数值ObjV作为适应度值的函数：F(个体) = ObjV，
#         其中F'为对F进行线性尺度变换后的适应度值函数，并且F'要满足以下两个条件：
#
#         1.为了保证适应度在平均值的个体在下一代的期望复制数为1，
#         因此要使得原适应度的平均值Favg = 新适应度的平均值F'avg。
#
#         2.为了控制适应度最大的个体在下一代中的复制数，
# ...
